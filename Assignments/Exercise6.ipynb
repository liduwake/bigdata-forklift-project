# %% [markdown]
# A spam filter flags emails as spam (**S**) based on keywords:
# - **5%** of all emails are spam.
# - If spam, the filter flags it **98%** of the time.
# - If not spam, the filter flags it **1%** of the time (false positive).
#
# **Question:**
# If an email is flagged, what is the probability it is actually spam?
#
# Verify your result using simulation.

# %%
#Simulation
