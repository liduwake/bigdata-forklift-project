# %% [markdown]
# ### **Naive Bayes Exercise: Predicting "Buy a Tablet"**
#
# **The Scenario:** A store wants to predict if a customer will buy a new tablet based on two features: **Age Group** and **Member Status**.
#
# **The Dataset:**
# | Row | Age Group | Member Status | Bought Tablet? |
# | :--- | :--- | :--- | :--- |
# | 1 | Young | Member | Yes |
# | 2 | Adult | Non-Member | Yes |
# | 3 | Young | Non-Member | No |
# | 4 | Adult | Member | Yes |
# | 5 | Adult | Member | No |
#
# **Goal:** Predict if a **Young Member** will buy a tablet.

# %% [markdown]
# ### Solution

# %% [markdown]
# **Ans Yes (0.144)**
