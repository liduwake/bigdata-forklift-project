# %% [markdown]
# # Big Data Processing with Apache Spark
#
# ## Objective
# This notebook demonstrates basic data processing using Apache Spark, including RDD and DataFrame operations.
#
# ## Environment
# - Python: pyspark_env
# - Spark: local mode

# %%
import sys
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("BigDataPractice")
    .master("local[1]")
    .config("spark.pyspark.python", sys.executable)
    .config("spark.pyspark.driver.python", sys.executable)
    .getOrCreate()
)

spark.sparkContext.setLogLevel("ERROR")

# %% [markdown]
# ## RDD Basics
#
# RDD is the fundamental distributed data structure in Spark. In this section, basic RDD actions are demonstrated.
